# %% [markdown]
# <a href="https://colab.research.google.com/github/artem-aliev/nlp-notes/blob/main/1_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install latexify-py
# Out:
# Requirement already satisfied: latexify-py in /usr/local/lib/python3.10/dist-packages (0.4.2)
# Requirement already satisfied: dill>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from latexify-py) (0.3.7)

# %%
import numpy as np
import matplotlib.pyplot as plt
import latexify
import math
# %matplotlib inline

# %%
g=9.78
def f(x):
  err = np.random.normal(0, 0.1)
  terr = np.random.normal(0, 0.1)
  return g*(x+terr)**2/2 + err

# %%
ys = np.arange(2, 20, 0.5)
xs=f(ys)
plt.scatter(xs, ys)

# %%
@latexify.function
def predict(x):
  return np.sqrt(x/5)
predict
# Out:
# $$ \displaystyle \mathrm{predict}(x) = \sqrt{ \frac{x}{5} } $$

# %%
yp=predict(xs)
plt.plot(xs, yp, color='black')
plt.scatter(xs, ys)

# %%
def mse (a, b):
  l = len(a)
  sum=0
  for i, j in zip(a,b):
    sum+=(i-j)**2
  return sum/l

# %%
@latexify.function
def mse2 (a,b):
  return np.sum( (a-b)**2) / len(a)
mse2
# Out:
# $$ \displaystyle \mathrm{mse2}(a, b) = \frac{\sum \mathopen{}\left( \mathopen{}\left( a - b \mathclose{}\right)^{2} \mathclose{}\right)}{\mathrm{len} \mathopen{}\left( a \mathclose{}\right)} $$

# %%
plt.plot(xs, (yp-ys)**2)

# %%
mse(ys, yp)
# Out:
# nan

# %%
mse2(ys,yp)
# Out:
# nan

# %%
def predict(a,b, x):
  return a*(x**.5) + b

def to_min (a, b):
  yp = predict(a,b,xs)
  return mse2(ys, yp)

# %%
sa = np.arange(-2, 2, 0.1)
sy= np.array([to_min(a, 0) for a in sa])
plt.plot(sa, sy)

# %%
# Import libraries
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

# Creating dataset
x = np.outer(np.linspace(0, 1, 32), np.ones(32))
y = x.copy().T # transpose
to_min_vec = np.vectorize(to_min)
z = to_min_vec(x, y)

# Creating figure
fig = plt.figure(figsize =(14, 9))
ax = plt.axes(projection ='3d')

# Creating color map
my_cmap = plt.get_cmap('hot')

# Creating plot
surf = ax.plot_surface(x, y, z,
                       cmap = my_cmap,
                       edgecolor ='none')

fig.colorbar(surf, ax = ax,
             shrink = 0.5, aspect = 5)

ax.set_title('Surface plot')

# show plot
plt.show()

# %%
x.shape
# Out:
# (32, 32)
